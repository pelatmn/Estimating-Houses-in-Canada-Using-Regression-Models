# %%
import numpy as np
import pandas as pd

veri = pd.read_excel (r'C:\Users\Pelin\Desktop\kanada verisi.xlsx')

# %%
print(veri)
# Out:
#           City      Price                     Address  Number_Beds  \
# 0      Toronto   779900.0       #318 -20 SOUTHPORT ST            3
# 1      Toronto   799999.0       #818 -60 SOUTHPORT ST            3
# 2      Toronto   799900.0     #714 -859 THE QUEENSWAY            2
# 3      Toronto  1200000.0            275 MORTIMER AVE            4
# 4      Toronto   668800.0       #420 -388 RICHMOND ST            1
# ...        ...        ...                         ...          ...
# 35763  Halifax   439900.0  301 60 Walter Havill Drive            2
# 35764  Halifax  6990000.0      1160 Rockcliffe Street            5
# 35765  Halifax   419900.0  212 60 Walter Havill Drive            2
# 35766  Halifax   949900.0           10 Idlewylde Road            3
# 35767  Halifax   592900.0     208 2842-2856 Gottingen            2
#
#        Number_Baths     Province  Population  Latitude  Longitude  \
# 0                 2      Ontario     5647656   43.7417   -79.3733
# ...

# %% [markdown]
# # Boxplot Grafikleri

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

figure = plt.figure(figsize=(10,5))
cerceve = pd.DataFrame(veri)
plt.boxplot(cerceve['Population'])
plt.title('Population Box-plot Grafiği')
plt.xlabel('Değişken')
plt.ylabel('Frekans')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

figure = plt.figure(figsize=(10,5))
cerceve = pd.DataFrame(veri)
plt.boxplot(cerceve['Price'])
plt.title('Price Box-plot Grafiği')
plt.xlabel('Değişken')
plt.ylabel('Frekans')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

figure = plt.figure(figsize=(10,5))
cerceve = pd.DataFrame(veri)
plt.boxplot(cerceve['Number_Beds'])
plt.title('Number_Beds Box-plot Grafiği')
plt.xlabel('Değişken')
plt.ylabel('Frekans')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

figure = plt.figure(figsize=(10,5))
cerceve = pd.DataFrame(veri)
plt.boxplot(cerceve['Number_Baths'])
plt.title('Number_Baths Box-plot Grafiği')
plt.xlabel('Değişken')
plt.ylabel('Frekans')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

figure = plt.figure(figsize=(10,5))
cerceve = pd.DataFrame(veri)
plt.boxplot(cerceve['Median_Family_Income'])
plt.title('Median_Family_Income Box-plot Grafiği')
plt.xlabel('Değişken')
plt.ylabel('Frekans')
plt.show()

# %% [markdown]
# # Histogram Grafikleri

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.hist(cerceve['Median_Family_Income'], bins=10, color='purple', edgecolor='black')

plt.title('Median_Family_Income Histogram Grafiği')
plt.xlabel('Değerler')
plt.ylabel('Frekans')

plt.show()

# %%
plt.hist(cerceve['Number_Baths'], bins=75, color='purple', edgecolor='black')

plt.title('Number_Baths Histogram Grafiği')
plt.xlabel('Değerler')
plt.ylabel('Frekans')

plt.show()

# %%
plt.hist(cerceve['Number_Beds'], bins=75, color='purple', edgecolor='black')

plt.title('Number_Beds Histogram Grafiği')
plt.xlabel('Değerler')
plt.ylabel('Frekans')

plt.show()

# %%
plt.hist(cerceve['Price'], bins=75, color='purple', edgecolor='black')

plt.title('Price Histogram Grafiği')
plt.xlabel('Değerler')
plt.ylabel('Frekans')

plt.show()

# %%
plt.hist(cerceve['Population'],bins=75, color='purple', edgecolor='black')

plt.title('Population Histogram Grafiği')
plt.xlabel('Değerler')
plt.ylabel('Frekans')

plt.show()

# %%
import matplotlib.pyplot as plt
x = range(len(cerceve['City']))
y = cerceve['City'] 
plt.bar(x,y)

plt.xlabel('Değerler')
plt.ylabel('Frekans')

plt.title('City Çubuk Grafiği')
plt.figure(figsize=(50, 45))
plt.show()

# %%
import matplotlib.pyplot as plt
x = range(len(cerceve['Province']))
y = cerceve['Province'] 
plt.bar(x,y)

plt.xlabel('Değerler')
plt.ylabel('Frekans')

plt.title('Province Çubuk Grafiği')
plt.figure(figsize=(50, 45))
plt.show()

# %%
import pandas as pd
print(type(cerceve))
Q1 = cerceve['Price'].quantile(0.25)
Q3 = cerceve['Price'].quantile(0.75)
IQR = Q3 - Q1

alt_sinir = Q1 - 1.5*IQR
ust_sinir = Q3 + 1.5*IQR

print(alt_sinir)
print(ust_sinir)

clean_data =cerceve[~((cerceve['Price'] < (alt_sinir)) | (cerceve['Price'] > (ust_sinir)))]
print(clean_data)
print(clean_data.describe().T)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# -492750.0
# 2047650.0
#           City      Price                     Address  Number_Beds  \
# 0      Toronto   779900.0       #318 -20 SOUTHPORT ST            3
# 1      Toronto   799999.0       #818 -60 SOUTHPORT ST            3
# 2      Toronto   799900.0     #714 -859 THE QUEENSWAY            2
# 3      Toronto  1200000.0            275 MORTIMER AVE            4
# 4      Toronto   668800.0       #420 -388 RICHMOND ST            1
# ...        ...        ...                         ...          ...
# 35762  Halifax   580000.0       3500 Claremont Street            3
# 35763  Halifax   439900.0  301 60 Walter Havill Drive            2
# 35765  Halifax   419900.0  212 60 Walter Havill Drive            2
# 35766  Halifax   949900.0           10 Idlewylde Road            3
# 35767  Halifax   592900.0     208 2842-2856 Gottingen            2
#
#        Number_Baths     Province  Population  Latitude  Longitude  \
# ...

# %% [markdown]
# # Z Score Normalizasyonu

# %%
import statistics
veri2 =clean_data['Price']
statistics.variance(veri2)
# Out:
# 179792853476.48676

# %%
import numpy as np
from sklearn import preprocessing
price2 = clean_data['Price'].astype(float)
print(price2)
# Out:
# 0         779900.0
# 1         799999.0
# 2         799900.0
# 3        1200000.0
# 4         668800.0
#            ...
# 35762     580000.0
# 35763     439900.0
# 35765     419900.0
# 35766     949900.0
# 35767     592900.0
# Name: Price, Length: 33298, dtype: float64

# %%
price2 = np.array(clean_data['Price']).reshape(-1,1)
print(preprocessing.normalize(price2))
# Out:
# [[1.]
#  [1.]
#  [1.]
#  ...
#  [1.]
#  [1.]
#  [1.]]

# %%
clean_data2 = clean_data.drop('Address', axis=1)
print(clean_data2)
# Out:
#           City      Price  Number_Beds  Number_Baths     Province  Population  \
# 0      Toronto   779900.0            3             2      Ontario     5647656
# 1      Toronto   799999.0            3             1      Ontario     5647656
# 2      Toronto   799900.0            2             2      Ontario     5647656
# 3      Toronto  1200000.0            4             2      Ontario     5647656
# 4      Toronto   668800.0            1             1      Ontario     5647656
# ...        ...        ...          ...           ...          ...         ...
# 35762  Halifax   580000.0            3             1  Nova Scotia      431479
# 35763  Halifax   439900.0            2             2  Nova Scotia      431479
# 35765  Halifax   419900.0            2             2  Nova Scotia      431479
# 35766  Halifax   949900.0            3             1  Nova Scotia      431479
# 35767  Halifax   592900.0            2             1  Nova Scotia      431479
#
# ...

# %% [markdown]
# # Modeller

# %%
import pandas as pd
import numpy as np
import seaborn as sns 

encoded_data = pd.get_dummies(clean_data2, columns = ["City" , "Province"]) 
print(encoded_data.head())
# Out:
#        Price  Number_Beds  Number_Baths  Population  Latitude  Longitude  \
# 0   779900.0            3             2     5647656   43.7417   -79.3733
# 1   799999.0            3             1     5647656   43.7417   -79.3733
# 2   799900.0            2             2     5647656   43.7417   -79.3733
# 3  1200000.0            4             2     5647656   43.7417   -79.3733
# 4   668800.0            1             1     5647656   43.7417   -79.3733
#
#    Median_Family_Income  City_Abbotsford  City_Airdrie  City_Barrie  ...  \
# 0                 97000                0             0            0  ...
# 1                 97000                0             0            0  ...
# 2                 97000                0             0            0  ...
# 3                 97000                0             0            0  ...
# 4                 97000                0             0            0  ...
#
#    City_Winnipeg  Province_Alberta  Province_British Columbia  \
# ...

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

y = encoded_data[['Price']]

from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
y_standardized = scaler.fit_transform(y)

# %%
x = encoded_data.copy()
x.drop('Price',axis=1, inplace=True)
print(x)
# Out:
#        Number_Beds  Number_Baths  Population  Latitude  Longitude  \
# 0                3             2     5647656   43.7417   -79.3733
# 1                3             1     5647656   43.7417   -79.3733
# 2                2             2     5647656   43.7417   -79.3733
# 3                4             2     5647656   43.7417   -79.3733
# 4                1             1     5647656   43.7417   -79.3733
# ...            ...           ...         ...       ...        ...
# 35762            3             1      431479   44.8857    63.1005
# 35763            2             2      431479   44.8857    63.1005
# 35765            2             2      431479   44.8857    63.1005
# 35766            3             1      431479   44.8857    63.1005
# 35767            2             1      431479   44.8857    63.1005
#
#        Median_Family_Income  City_Abbotsford  City_Airdrie  City_Barrie  \
# 0                     97000                0             0            0
# ...

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
x_standardized = scaler.fit_transform(x)

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression 

x = encoded_data.copy()
x.drop('Price',axis=1, inplace=True)
y = encoded_data[['Price']]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)


model = LinearRegression()
model.fit(X_train, y_train)


predictions = model.predict(X_test)


print("Predictions:", predictions)

from sklearn.metrics import mean_squared_error, r2_score , mean_absolute_error


MSE = mean_squared_error(y_test, predictions)

R_squared = r2_score(y_test, predictions)

MAE = mean_absolute_error(y_test, predictions)

print("Mean Squared Error (MSE):", MSE)
print("R-squared:", R_squared)
print("Mean Absolute Error (MAE):", MAE)
# Out:
# Predictions: [[  261464.97552955]
#  [  572744.25743845]
#  [  456600.63908438]
#  ...
#  [-1828425.50962983]
#  [-1907417.5548306 ]
#  [-1965489.36400763]]
# Mean Squared Error (MSE): 193341044544.62726
# R-squared: 0.09994557195883491
# Mean Absolute Error (MAE): 269284.4229887335

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsRegressor




X_train, X_test, y_train, y_test = train_test_split(x_standardized, y_standardized, test_size=0.2 ,shuffle=False)

k = 25
model = KNeighborsRegressor(n_neighbors=k)
model.fit(X_train, y_train)


predictions = model.predict(X_test)
print("Predictions:", predictions)


from sklearn.metrics import mean_squared_error, r2_score , mean_absolute_error
MSE = mean_squared_error(y_test, predictions)

R_squared = r2_score(y_test, predictions)

MAE = mean_absolute_error(y_test, predictions)

print("Mean Squared Error (MSE):", MSE)
print("R-squared:", R_squared)
print("Mean Absolute Error (MAE):", MAE)
# Out:
# Predictions: [[-0.99588168]
#  [-0.41797565]
#  [-0.5081425 ]
#  ...
#  [-0.37267531]
#  [-0.52771735]
#  [-0.82908709]]
# Mean Squared Error (MSE): 0.4887040873615857
# R-squared: 0.5909747997948454
# Mean Absolute Error (MAE): 0.47875985824595213

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error


X_train, X_test, y_train, y_test = train_test_split(x_standardized, y_standardized, test_size=0.2, shuffle=False)


model = RandomForestRegressor(n_estimators=100, random_state=42)
model.fit(X_train, y_train)


predictions = model.predict(X_test)
print("Predictions:", predictions)


mse = mean_squared_error(y_test, predictions)
r_squared = r2_score(y_test, predictions)
mae = mean_absolute_error(y_test, predictions)


print("Mean Squared Error (MSE):", mse)
print("R-squared:", r_squared)
print("Mean Absolute Error (MAE):", mae)
# Out:
# C:\Users\Pelin\AppData\Local\Temp\ipykernel_13504\2921285190.py:11: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model.fit(X_train, y_train)
# Predictions: [-0.9766656  -0.46246381 -0.50789226 ... -0.86433662 -1.09825549
#  -1.17416119]
# Mean Squared Error (MSE): 0.433314999999723
# R-squared: 0.6373331854381481
# Mean Absolute Error (MAE): 0.44282169396598176

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

x = encoded_data.copy()
x.drop('Price',axis=1, inplace=True)
y = encoded_data[['Price']]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

model = MLPRegressor(hidden_layer_sizes=(100, ), activation='relu', solver='adam', learning_rate='constant', random_state = 42)
model.fit(X_train, y_train)

predictions = model.predict(X_test)
print("Predictions:", predictions)

mse = mean_squared_error(y_test, predictions)
r_squared = r2_score(y_test, predictions)
mae = mean_absolute_error(y_test, predictions)

print("Mean Squared Error (MSE):", mse)
print("R-squared:", r_squared)
print("Mean Absolute Error (MAE):", mae)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1599: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Predictions: [663979.86987938 666123.16098605 665062.11527628 ... 731610.17214364
#  731586.31949872 730997.64425011]
# Mean Squared Error (MSE): 199757002106.94495
# R-squared: 0.07007756836089585
# Mean Absolute Error (MAE): 352476.23649841466
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

X_train, X_test, y_train, y_test = train_test_split(x_standardized, y_standardized, test_size=0.2, shuffle=False)


model = GradientBoostingRegressor(n_estimators=100, learning_rate=0.1, max_depth=3, random_state=42)
model.fit(X_train, y_train)


predictions = model.predict(X_test)

mse = mean_squared_error(y_test, predictions)
r_squared = r2_score(y_test, predictions)
mae = mean_absolute_error(y_test, predictions)


print("Mean Squared Error (MSE):", mse)
print("R-squared:", r_squared)
print("Mean Absolute Error (MAE):", mae)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Mean Squared Error (MSE): 0.46280818848979016
# R-squared: 0.6126486009650239
# Mean Absolute Error (MAE): 0.45991728017146705

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error


X_train, X_test, y_train, y_test = train_test_split(x_standardized, y_standardized, test_size=0.2, shuffle=False)

model = SVR(kernel='linear')
model.fit(X_train, y_train)

predictions = model.predict(X_test)

mse = mean_squared_error(y_test, predictions)
r_squared = r2_score(y_test, predictions)
mae = mean_absolute_error(y_test, predictions)

print("Mean Squared Error (MSE):", mse)
print("R-squared:", r_squared)
print("Mean Absolute Error (MAE):", mae)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Mean Squared Error (MSE): 0.939268175608727
# R-squared: 0.21387120854907649
# Mean Absolute Error (MAE): 0.6843577623998425
